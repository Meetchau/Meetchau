# %% [markdown]
# <a href="https://colab.research.google.com/github/Meetchau/Meetchau/blob/main/Practice1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from numpy.random import randn

# %%
np.random.seed(10)

# %%
df = pd.DataFrame(randn(3,3),['A','B','C'],['X','Y','Z'])

# %%
df
# Out:
#           X         Y         Z
# A -0.174600  0.433026  1.203037
# B -0.965066  1.028274  0.228630
# C  0.445138 -1.136602  0.135137

# %%
df['Y']
# Out:
# A    0.433026
# B    1.028274
# C   -1.136602
# Name: Y, dtype: float64

# %%
type(df['Y'])
# Out:
# pandas.core.series.Series

# %%
df[['X','Y']]
# Out:
#           X         Y
# A -0.174600  0.433026
# B -0.965066  1.028274
# C  0.445138 -1.136602

# %%
type(df[['X','Y']])
# Out:
# pandas.core.frame.DataFrame

# %%
df["K"] = df['Y'] + df['X']

# %%
df
# Out:
#           X         Y         Z         K
# A -0.174600  0.433026  1.203037  0.258426
# B -0.965066  1.028274  0.228630  0.063208
# C  0.445138 -1.136602  0.135137 -0.691465

# %%
df.drop('X', axis = 1)
# Out:
#           Y         Z         K
# A  0.433026  1.203037  0.258426
# B  1.028274  0.228630  0.063208
# C -1.136602  0.135137 -0.691465

# %%
df.drop('B')
# Out:
#           X         Y         Z         K
# A -0.174600  0.433026  1.203037  0.258426
# C  0.445138 -1.136602  0.135137 -0.691465

# %%
df
# Out:
#           X         Y         Z         K
# A -0.174600  0.433026  1.203037  0.258426
# B -0.965066  1.028274  0.228630  0.063208
# C  0.445138 -1.136602  0.135137 -0.691465

# %%
x = df.drop('B')
x
# Out:
#           X         Y         Z         K
# A -0.174600  0.433026  1.203037  0.258426
# C  0.445138 -1.136602  0.135137 -0.691465

# %%
x
# Out:
#           X         Y         Z         K
# A -0.174600  0.433026  1.203037  0.258426
# C  0.445138 -1.136602  0.135137 -0.691465

# %%
y = x.drop(['Y','Z'],axis = 1)

# %%
y
# Out:
#           X         K
# A -0.174600  0.258426
# C  0.445138 -0.691465

# %%
df = pd.DataFrame(randn(5,5),['A','B','C','D','E'],['X','Y','Z','J','K'])
df
# Out:
#           X         Y         Z         J         K
# A -0.174600  0.433026  1.203037 -0.965066  1.028274
# B  0.228630  0.445138 -1.136602  0.135137  1.484537
# C -1.079805 -1.977728 -1.743372  0.266070  2.384967
# D  1.123691  1.672622  0.099149  1.397996 -0.271248
# E  0.613204 -0.267317 -0.549309  0.132708 -0.476142

# %%
df
# Out:
#           X         Y         Z         J         K
# A  1.484537 -1.079805 -1.977728 -1.743372  0.266070
# B  2.384967  1.123691  1.672622  0.099149  1.397996
# C -0.271248  0.613204 -0.267317 -0.549309  0.132708
# D -0.476142  1.308473  0.195013  0.400210 -0.337632
# E  1.256472 -0.731970  0.660232 -0.350872 -0.939433

# %%
newdf = df>0
newdf
# Out:
#        X      Y      Z      J      K
# A   True  False  False  False   True
# B   True   True   True   True   True
# C  False   True  False  False   True
# D  False   True   True   True  False
# E   True  False   True  False  False

# %%
df[newdf]
# Out:
#           X         Y         Z         J         K
# A  1.484537       NaN       NaN       NaN  0.266070
# B  2.384967  1.123691  1.672622  0.099149  1.397996
# C       NaN  0.613204       NaN       NaN  0.132708
# D       NaN  1.308473  0.195013  0.400210       NaN
# E  1.256472       NaN  0.660232       NaN       NaN

# %%
File = "CA AK KK MS MC".split()

# %%
File
# Out:
# ['CA', 'AK', 'KK', 'MS', 'MC']

# %%
df["Names"] = File

# %%
df
# Out:
#           X         Y         Z         J         K Names
# A -0.174600  0.433026  1.203037 -0.965066  1.028274    CA
# B  0.228630  0.445138 -1.136602  0.135137  1.484537    AK
# C -1.079805 -1.977728 -1.743372  0.266070  2.384967    KK
# D  1.123691  1.672622  0.099149  1.397996 -0.271248    MS
# E  0.613204 -0.267317 -0.549309  0.132708 -0.476142    MC

# %%
df.set_index("Names")
# Out:
#               X         Y         Z         J         K
# Names
# CA    -0.174600  0.433026  1.203037 -0.965066  1.028274
# AK     0.228630  0.445138 -1.136602  0.135137  1.484537
# KK    -1.079805 -1.977728 -1.743372  0.266070  2.384967
# MS     1.123691  1.672622  0.099149  1.397996 -0.271248
# MC     0.613204 -0.267317 -0.549309  0.132708 -0.476142

# %%
a = {"A":[1,2,np.nan],"B":[3,5,np.nan],"C":["J",5,9]}

# %%
df = pd.DataFrame(a)
df
# Out:
#      A    B  C
# 0  1.0  3.0  J
# 1  2.0  5.0  5
# 2  NaN  NaN  9

# %%
df.fillna(value = "3")
# Out:
#      A    B  C
# 0  1.0  3.0  J
# 1  2.0  5.0  5
# 2    3    3  9

# %%
df
# Out:
#      A    B  C
# 0  1.0  3.0  J
# 1  2.0  5.0  5
# 2  NaN  NaN  9

# %%
df["A"].fillna(value = df["A"].mean())
df["B"].fillna(value = df["B"].mean())
# Out:
# 0    3.0
# 1    5.0
# 2    4.0
# Name: B, dtype: float64

# %% [markdown]
# # Group By

# %%
data = {"Company":["Google","Google","Microsoft","Microsoft","Facebook","Facebook"],
        "Person":["Sam","Charlie","Amy","Vanessa","Carl","Sarah"],
        "Sales":[200,120,340,124,243,350]}

data
# Out:
# {'Company': ['Google',
#   'Google',
#   'Microsoft',
#   'Microsoft',
#   'Facebook',
#   'Facebook'],
#  'Person': ['Sam', 'Charlie', 'Amy', 'Vanessa', 'Carl', 'Sarah'],
#  'Sales': [200, 120, 340, 124, 243, 350]}

# %%
print(data)
# Out:
# {'Company': ['Google', 'Google', 'Microsoft', 'Microsoft', 'Facebook', 'Facebook'], 'Person': ['Sam', 'Charlie', 'Amy', 'Vanessa', 'Carl', 'Sarah'], 'Sales': [200, 120, 340, 124, 243, 350]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#      Company   Person  Sales
# 0     Google      Sam    200
# 1     Google  Charlie    120
# 2  Microsoft      Amy    340
# 3  Microsoft  Vanessa    124
# 4   Facebook     Carl    243
# 5   Facebook    Sarah    350

# %%
df.groupby("Company").count()
# Out:
#            Person  Sales
# Company
# Facebook        2      2
# Google          2      2
# Microsoft       2      2

# %%
df.groupby("Company").sum()
# Out:
#                Person  Sales
# Company
# Facebook    CarlSarah    593
# Google     SamCharlie    320
# Microsoft  AmyVanessa    464

# %%
df.groupby("Company").max()
# Out:
#             Person  Sales
# Company
# Facebook     Sarah    350
# Google         Sam    200
# Microsoft  Vanessa    340

# %%
df.groupby("Company").describe().transpose()
# Out:
# Company        Facebook      Google   Microsoft
# Sales count    2.000000    2.000000    2.000000
#       mean   296.500000  160.000000  232.000000
#       std     75.660426   56.568542  152.735065
#       min    243.000000  120.000000  124.000000
#       25%    269.750000  140.000000  178.000000
#       50%    296.500000  160.000000  232.000000
#       75%    323.250000  180.000000  286.000000
#       max    350.000000  200.000000  340.000000

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3'],
                        'C': ['C0', 'C1', 'C2', 'C3'],
                        'D': ['D0', 'D1', 'D2', 'D3']},
                        index=[0, 1, 2, 3])

# %%
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                        'B': ['B4', 'B5', 'B6', 'B7'],
                        'C': ['C4', 'C5', 'C6', 'C7'],
                        'D': ['D4', 'D5', 'D6', 'D7']},
                         index=[4, 5, 6, 7])

# %%
df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                        'B': ['B8', 'B9', 'B10', 'B11'],
                        'C': ['C8', 'C9', 'C10', 'C11'],
                        'D': ['D8', 'D9', 'D10', 'D11']},
                        index=[8, 9, 10, 11])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %% [markdown]
# # Pandas Operation

# %%
df = pd.DataFrame({'col1':[1,2,3,4],
                  'col2':[444,555,666,444],
                  'col3':['abc','def','ghi','xyz']})
df.head()
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df['col1'][2]
# Out:
# 3

# %%
df["col2"].nunique()
# Out:
# 3

# %%
df["col2"].unique()
# Out:
# array([444, 555, 666])

# %%
df["col1"].value_counts()
# Out:
# col1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: count, dtype: int64

# %%
def times2(x):
  return x*2

# %%
df["col1"].apply(times2)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# Name: col1, dtype: int64

# %%
df["col1"].apply(times2)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# Name: col1, dtype: int64

# %%
df.sort_values(by="col1")
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df["col1"].apply(lambda x: x**3)
# Out:
# 0     1
# 1     8
# 2    27
# 3    64
# Name: col1, dtype: int64
